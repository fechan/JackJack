# %%
import pandas as pd

WaypointEdge = pd.read_csv("WaypointEdge.csv", usecols=["Start", "End", "PlayerConditionID"])
PlayerCondition = pd.read_csv("PlayerCondition.csv", usecols=["ID", "RaceMask"])
ChrRaces = pd.read_csv("ChrRaces.csv", usecols=["ID", "PlayableRaceBit"])
ChrRaces = ChrRaces[ChrRaces["PlayableRaceBit"] != -1] # remove unplayable races

PlayerCondition_reduced = PlayerCondition[PlayerCondition.ID.isin(WaypointEdge.PlayerConditionID)]
# WaypointEdge_prereq = WaypointEdge.merge(PlayerCondition, how="inner", left_on="PlayerConditionID", right_on="ID").drop(columns=["ID", "PlayerConditionID"])

# %%
def in_race_bit_mask(bitmask, raceID):
    if bitmask == 0: return True
    race_bit = ChrRaces[ChrRaces.ID == raceID].PlayableRaceBit
    return bitmask & (2**race_bit) == (2**race_bit)

# %%
def expand_racemask(PlayerCondition):
    newdf = PlayerCondition.copy()
    for index, race in ChrRaces.iterrows():
        newdf["race_" + str(race["ID"])] = newdf.apply(lambda x, y: in_race_bit_mask(x.RaceMask, y), args=([race["ID"]]), axis=1)
    return newdf

expand_racemask(PlayerCondition_reduced)
# Out:
#           ID             RaceMask  race_1  race_2  race_3  race_4  race_5  \
# 1        923 -6184943489809468494   False    True   False   False    True
# 2        924  6130900294268439629    True   False    True    True   False
# 2245   30948 -6184943489809468494   False    True   False   False    True
# 2246   30949  6130900294268439629    True   False    True    True   False
# 6117   49081                    0    True    True    True    True    True
# 9845   69093 -6184943489809468494   False    True   False   False    True
# 9846   69094  6130900294268439629    True   False    True    True   False
# 9956   69533  6130900294268439629    True   False    True    True   False
# 9957   69534  6130900294268439629    True   False    True    True   False
# 9958   69535                    0    True    True    True    True    True
# 10142  70244 -6184943489809468494   False    True   False   False    True
# 10143  70245 -6184943489809468494   False    True   False   False    True
# 13533  80945                    0    True    True    True    True    True
# 13620  81254                    0    True    True    True    True    True
# 13621  81255                    0    True    True    True    True    True
# 13622  81256                    0    True    True    True    True    True
# 13623  81257                    0    True    True    True    True    True
# 13624  81258                    0    True    True    True    True    True
# 13625  81259                    0    True    True    True    True    True
# 13626  81260                    0    True    True    True    True    True
# 13627  81261                    0    True    True    True    True    True
# 13628  81262                    0    True    True    True    True    True
# 13629  81263                    0    True    True    True    True    True
# 13630  81264                    0    True    True    True    True    True
# 13631  81265                    0    True    True    True    True    True
# 13632  81266                    0    True    True    True    True    True
# 13633  81267                    0    True    True    True    True    True
# 13634  81268                    0    True    True    True    True    True
# 13635  81269                    0    True    True    True    True    True
# 13636  81270                    0    True    True    True    True    True
# 13637  81271                    0    True    True    True    True    True
# 13638  81272                    0    True    True    True    True    True
# 13639  81273                    0    True    True    True    True    True
# 13640  81275                    0    True    True    True    True    True
# 13641  81276                    0    True    True    True    True    True
# 13642  81277                    0    True    True    True    True    True
# 13643  81278                    0    True    True    True    True    True
# 14806  83810                    0    True    True    True    True    True
# 16358  87423                    0    True    True    True    True    True
# 16376  87481                    0    True    True    True    True    True
# 16427  87609  6130900294268439629    True   False    True    True   False
# 16429  87617 -6184943489809468494   False    True   False   False    True
# 16897  88449                    0    True    True    True    True    True
# 17891  90924                    0    True    True    True    True    True
# 17892  90925                    0    True    True    True    True    True
# 18889  93068                    0    True    True    True    True    True
#
#        race_6  race_7  race_8  ...  race_27  race_28  race_29  race_30  \
# 1        True   False    True  ...     True     True    False    False
# 2       False    True   False  ...    False    False     True     True
# 2245     True   False    True  ...     True     True    False    False
# 2246    False    True   False  ...    False    False     True     True
# 6117     True    True    True  ...     True     True     True     True
# 9845     True   False    True  ...     True     True    False    False
# 9846    False    True   False  ...    False    False     True     True
# 9956    False    True   False  ...    False    False     True     True
# 9957    False    True   False  ...    False    False     True     True
# 9958     True    True    True  ...     True     True     True     True
# 10142    True   False    True  ...     True     True    False    False
# 10143    True   False    True  ...     True     True    False    False
# 13533    True    True    True  ...     True     True     True     True
# 13620    True    True    True  ...     True     True     True     True
# 13621    True    True    True  ...     True     True     True     True
# 13622    True    True    True  ...     True     True     True     True
# 13623    True    True    True  ...     True     True     True     True
# 13624    True    True    True  ...     True     True     True     True
# 13625    True    True    True  ...     True     True     True     True
# 13626    True    True    True  ...     True     True     True     True
# 13627    True    True    True  ...     True     True     True     True
# 13628    True    True    True  ...     True     True     True     True
# 13629    True    True    True  ...     True     True     True     True
# 13630    True    True    True  ...     True     True     True     True
# 13631    True    True    True  ...     True     True     True     True
# 13632    True    True    True  ...     True     True     True     True
# 13633    True    True    True  ...     True     True     True     True
# 13634    True    True    True  ...     True     True     True     True
# 13635    True    True    True  ...     True     True     True     True
# 13636    True    True    True  ...     True     True     True     True
# 13637    True    True    True  ...     True     True     True     True
# 13638    True    True    True  ...     True     True     True     True
# 13639    True    True    True  ...     True     True     True     True
# 13640    True    True    True  ...     True     True     True     True
# 13641    True    True    True  ...     True     True     True     True
# 13642    True    True    True  ...     True     True     True     True
# 13643    True    True    True  ...     True     True     True     True
# 14806    True    True    True  ...     True     True     True     True
# 16358    True    True    True  ...     True     True     True     True
# 16376    True    True    True  ...     True     True     True     True
# 16427   False    True   False  ...    False    False     True     True
# 16429    True   False    True  ...     True     True    False    False
# 16897    True    True    True  ...     True     True     True     True
# 17891    True    True    True  ...     True     True     True     True
# 17892    True    True    True  ...     True     True     True     True
# 18889    True    True    True  ...     True     True     True     True
#
#        race_31  race_32  race_34  race_35  race_36  race_37
# 1         True    False    False     True     True    False
# 2        False     True     True    False    False     True
# 2245      True    False    False     True     True    False
# 2246     False     True     True    False    False     True
# 6117      True     True     True     True     True     True
# 9845      True    False    False     True     True    False
# 9846     False     True     True    False    False     True
# 9956     False     True     True    False    False     True
# 9957     False     True     True    False    False     True
# 9958      True     True     True     True     True     True
# 10142     True    False    False     True     True    False
# 10143     True    False    False     True     True    False
# 13533     True     True     True     True     True     True
# 13620     True     True     True     True     True     True
# 13621     True     True     True     True     True     True
# 13622     True     True     True     True     True     True
# 13623     True     True     True     True     True     True
# 13624     True     True     True     True     True     True
# 13625     True     True     True     True     True     True
# 13626     True     True     True     True     True     True
# 13627     True     True     True     True     True     True
# 13628     True     True     True     True     True     True
# 13629     True     True     True     True     True     True
# 13630     True     True     True     True     True     True
# 13631     True     True     True     True     True     True
# 13632     True     True     True     True     True     True
# 13633     True     True     True     True     True     True
# 13634     True     True     True     True     True     True
# 13635     True     True     True     True     True     True
# 13636     True     True     True     True     True     True
# 13637     True     True     True     True     True     True
# 13638     True     True     True     True     True     True
# 13639     True     True     True     True     True     True
# 13640     True     True     True     True     True     True
# 13641     True     True     True     True     True     True
# 13642     True     True     True     True     True     True
# 13643     True     True     True     True     True     True
# 14806     True     True     True     True     True     True
# 16358     True     True     True     True     True     True
# 16376     True     True     True     True     True     True
# 16427    False     True     True    False    False     True
# 16429     True    False    False     True     True    False
# 16897     True     True     True     True     True     True
# 17891     True     True     True     True     True     True
# 17892     True     True     True     True     True     True
# 18889     True     True     True     True     True     True
#
# [46 rows x 27 columns]
